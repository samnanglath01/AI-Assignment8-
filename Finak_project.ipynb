# %%
import pandas as pd

# Adjust the path to where you've stored the CSV files
X_train = pd.read_csv('weatherAUS_X_train.csv')
y_train = pd.read_csv('weatherAUS_y_train.csv')
df = X_train.merge(y_train, left_index=True, right_index=True)
df.head()
# Out:
# /var/folders/fl/_bj3sz253sz1whgpd0_2l55r0000gn/T/ipykernel_1499/2869948924.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#          Date          Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0  2017-04-24            Albany     14.5     17.8      14.2          NaN
# 1  2013-10-11         Katherine     24.6     39.5       0.0         12.0
# 2  2012-02-18  MelbourneAirport     14.7     26.6       0.2          3.2
# 3  2012-02-18       Williamtown     18.3     26.6       0.0          NaN
# 4  2011-10-11          Adelaide     11.4     19.3       0.6          2.4
#
# ...

# %%
#handle missing data

# %%
df.describe()
# Out:
#             MinTemp        MaxTemp       Rainfall   Evaporation      Sunshine  \
# count  115190.00000  115370.000000  113764.000000  66039.000000  60426.000000
# mean       12.19708      23.219542       2.378870      5.465219      7.612980
# std         6.39974       7.117535       8.537384      4.195541      3.785258
# min        -8.50000      -4.800000       0.000000      0.000000      0.000000
# 25%         7.60000      17.900000       0.000000      2.600000      4.800000
# 50%        12.00000      22.600000       0.000000      4.800000      8.400000
# 75%        16.90000      28.200000       0.800000      7.400000     10.600000
# max        31.90000      47.300000     371.000000    145.000000     14.500000
#
#        WindGustSpeed   WindSpeed9am   WindSpeed3pm    Humidity9am  \
# count  108166.000000  114960.000000  113911.000000  114251.000000
# mean       40.036056      14.052157      18.663492      68.908062
# std        13.631077       8.918674       8.819087      19.015417
# ...

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
##DATA PREPROCESSInG


# Function to impute missing values
from sklearn.compose import ColumnTransformer
from sklearn.discriminant_analysis import StandardScaler
from sklearn.preprocessing import OneHotEncoder


def fill_missing_values(df):
    for column in df.columns:
        if df[column].dtype in ['float64', 'int64']:
            df[column] = df[column].fillna(df[column].median())
        elif df[column].dtype == 'object':
            df[column] = df[column].fillna(df[column].mode()[0])
    return df
df = fill_missing_values(df)
print(df.isnull().sum())
if df.isnull().sum().any():
    print("There are still missing values in the dataset.")
else:
    print("No missing values found.")
X = df.drop(columns=['RainTomorrow'])  # Drop the target column
y = df['RainTomorrow'] 
categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
numerical_cols = X.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Create transformers
numerical_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])


# Apply transformations
X_preprocessed = preprocessor.fit_transform(X)
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64
# No missing values found.

# %%
#encode target
from sklearn.preprocessing import LabelEncoder

# Create label encoder object
label_encoder = LabelEncoder()

# Fit and transform the target variable
y_encoded = label_encoder.fit_transform(y)

# Checking the mapping
print(dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_))))
# Out:
# {'No': 0, 'Yes': 1}

# %%
# Split the data into training and testing sets, ensuring balanced classes
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Initialize classifiers
decision_tree = DecisionTreeClassifier(random_state=42)
svm = make_pipeline(StandardScaler(with_mean=False), SVC(random_state=42))
mlp = make_pipeline(StandardScaler(with_mean=False), MLPClassifier(random_state=42))
logistic_regression = make_pipeline(StandardScaler(with_mean=False), LogisticRegression(random_state=42))
naive_bayes = GaussianNB()
bagging = BaggingClassifier(DecisionTreeClassifier(random_state=42), n_estimators=10, random_state=42)

# Dictionary to hold classifiers
classifiers = {
    'Decision Tree': decision_tree,
    'SVM': svm,
    'MLP': mlp,
    'Logistic Regression': logistic_regression,
    'Naive Bayes': naive_bayes,
    'Bagging': bagging
}

# Ensure X_train is dense for models that don't support sparse matrices
if hasattr(X_train, "toarray"):  # Check if X_train is sparse
    X_train_dense = X_train.toarray()
else:
    X_train_dense = X_train

# Train each model and evaluate on the testing set
for name, clf in classifiers.items():
    try:
        # Check if the classifier can handle sparse data, use dense if not
        if 'Naive Bayes' in name:
            clf.fit(X_train_dense, y_train)
        else:
            clf.fit(X_train, y_train)

        # Predict on testing data
        if hasattr(X_test, "toarray"):
            y_pred = clf.predict(X_test.toarray())
        else:
            y_pred = clf.predict(X_test)

        # Evaluate accuracy
        accuracy = accuracy_score(y_test, y_pred)
        print(f'Accuracy of {name}: {accuracy:.2f}')
    except Exception as e:
        print(f'Error training {name}: {e}')
# Out:
# Accuracy of Decision Tree: 0.81
# Accuracy of SVM: 0.85
# Accuracy of MLP: 0.85
# Accuracy of Logistic Regression: 0.85
# Accuracy of Naive Bayes: 0.44
# Accuracy of Bagging: 0.85

# %%
from sklearn.model_selection import GridSearchCV

# Decision Tree Grid Search
param_grid_dt = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5, 10]
}
grid_search_dt = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid_dt, cv=5, scoring='accuracy')
grid_search_dt.fit(X_train, y_train)
print("Best Decision Tree Accuracy:", grid_search_dt.best_score_)
print("Best parameters:", grid_search_dt.best_params_)
# SVM Grid Search
param_grid_svm = {
    'svc__C': [0.1, 1, 10, 100],
    'svc__kernel': ['linear', 'rbf']
}
svm_pipeline = make_pipeline(StandardScaler(with_mean=False), SVC(random_state=42))
grid_search_svm = GridSearchCV(svm_pipeline, param_grid_svm, cv=5, scoring='accuracy')
grid_search_svm.fit(X_train, y_train)
print("Best SVM Accuracy:", grid_search_svm.best_score_)
print("Best parameters:", grid_search_svm.best_params_)
# MLP Grid Search
from sklearn.neural_network import MLPClassifier

param_grid_mlp = {
    'mlpclassifier__alpha': [0.0001, 0.001, 0.01],
    'mlpclassifier__hidden_layer_sizes': [(50,), (100,), (50, 50)],
    'mlpclassifier__activation': ['tanh', 'relu']
}
mlp_pipeline = make_pipeline(StandardScaler(with_mean=False), MLPClassifier(random_state=42))
grid_search_mlp = GridSearchCV(mlp_pipeline, param_grid_mlp, cv=5, scoring='accuracy')
grid_search_mlp.fit(X_train, y_train)
print("Best MLP Accuracy:", grid_search_mlp.best_score_)
print("Best parameters:", grid_search_mlp.best_params_)
# Logistic Regression Grid Search
param_grid_lr = {
    'logisticregression__C': [0.01, 0.1, 1, 10, 100],
    'logisticregression__penalty': ['l1', 'l2'],
    'logisticregression__solver': ['liblinear']  # liblinear supports both l1 and l2
}
lr_pipeline = make_pipeline(StandardScaler(with_mean=False), LogisticRegression(random_state=42))
grid_search_lr = GridSearchCV(lr_pipeline, param_grid_lr, cv=5, scoring='accuracy')
grid_search_lr.fit(X_train, y_train)
print("Best Logistic Regression Accuracy:", grid_search_lr.best_score_)
print("Best parameters:", grid_search_lr.best_params_)
# Bagging Grid Search
from sklearn.ensemble import BaggingClassifier

param_grid_bagging = {
    'n_estimators': [10, 50, 100],
    'base_estimator__max_depth': [3, 5, 10]
}
bagging = BaggingClassifier(DecisionTreeClassifier(random_state=42), random_state=42)
grid_search_bagging = GridSearchCV(bagging, param_grid_bagging, cv=5, scoring='accuracy')
grid_search_bagging.fit(X_train, y_train)
print("Best Bagging Accuracy:", grid_search_bagging.best_score_)
print("Best parameters:", grid_search_bagging.best_params_)
# Out:
# Best Decision Tree Accuracy: 0.8394311123339442
# Best parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
# Evaluate classifiers and print accuracies
def evaluate_and_compare_classifiers(original_classifiers, modified_classifiers, X_train, y_train, X_test, y_test):
    results = {}
    for name in original_classifiers.keys():
        original_clf = original_classifiers[name]
        modified_clf = modified_classifiers[name]
        
        # Train and evaluate the original classifier
        original_clf.fit(X_train, y_train)
        y_pred_original = original_clf.predict(X_test)
        accuracy_original = accuracy_score(y_test, y_pred_original)
        
        # Train and evaluate the modified classifier
        modified_clf.fit(X_train, y_train)
        y_pred_modified = modified_clf.predict(X_test)
        accuracy_modified = accuracy_score(y_test, y_pred_modified)
        
        # Store results
        results[name] = (accuracy_original, accuracy_modified)

        # Print results
        print(f'{name}:')
        print(f'  Original Accuracy: {accuracy_original:.2f}')
        print(f'  Modified Accuracy: {accuracy_modified:.2f}')
        print(f'  Improvement: {accuracy_modified - accuracy_original:.2f}\n')

    return results

# Example usage
results = evaluate_and_compare_classifiers(classifiers , classifiers_modified, X_train, y_train, X_test, y_test)
# Out:
# Decision Tree:
#   Original Accuracy: 0.81
#   Modified Accuracy: 0.84
#   Improvement: 0.03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 30
#      27     return results
#      29 # Example usage
# ---> 30 results = evaluate_and_compare_classifiers(classifiers , classifiers_modified, X_train, y_train, X_test, y_test)
#
# Cell In[11], line 10, in evaluate_and_compare_classifiers(original_classifiers, modified_classifiers, X_train, y_train, X_test, y_test)
#       8 # Train and evaluate the original classifier
#       9 original_clf.fit(X_train, y_train)
# ---> 10 y_pred_original = original_clf.predict(X_test)
#      11 accuracy_original = accuracy_score(y_test, y_pred_original)
#      13 # Train and evaluate the modified classifier
#
# ...

# %%
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# Ensemble methods
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

#  TRee Evaluation
# Decision Tree
dt_clf = DecisionTreeClassifier()
dt_clf.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19172\506956864.py in ?()
#      13
#      14 #  TRee Evaluation
#      15 # Decision Tree
#      16 dt_clf = DecisionTreeClassifier()
# ---> 17 dt_clf.fit(x_train, y_train)
#
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
#    1005         self : DecisionTreeClassifier
#    1006             Fitted estimator.
# ...
